# %%
import requests
import pandas as pd

# %% [markdown]
# ## 1. Parse data

# %%
url = "https://th-api.upbit.com/v1/candles/days?market=THB-BTC&count=200"
headers = {}

# %%
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data)
# Out:
# [{'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-10T00:00:00',
#   'opening_price': 917600.0,
#   'high_price': 923960.0,
#   'low_price': 917520.0,
#   'trade_price': 923960.0,
#   'timestamp': 1694323698157,
#   'candle_acc_trade_price': 25661.6196062,
#   'candle_acc_trade_volume': 0.02786802,
#   'prev_closing_price': 917580.0,
#   'change_price': 6380.0,
#   'change_rate': 0.0069530722},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-09T00:00:00',
#   'opening_price': 917520.0,
#   'high_price': 923420.0,
#   'low_price': 917500.0,
#   'trade_price': 917580.0,
#   'timestamp': 1694290345099,
#   'candle_acc_trade_price': 166487.9907826,
#   'candle_acc_trade_volume': 0.18090188,
#   'prev_closing_price': 916720.0,
#   'change_price': 860.0,
#   'change_rate': 0.0009381272},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-08T00:00:00',
#   'opening_price': 937040.0,
#   'high_price': 937040.0,
#   'low_price': 916720.0,
#   'trade_price': 916720.0,
#   'timestamp': 1694168754739,
#   'candle_acc_trade_price': 139988.0744926,
#   'candle_acc_trade_volume': 0.15109143,
#   'prev_closing_price': 931240.0,
#   'change_price': -14520.0,
#   'change_rate': -0.0155921137},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-07T00:00:00',
#   'opening_price': 918220.0,
#   'high_price': 931900.0,
#   'low_price': 907180.0,
#   'trade_price': 931240.0,
#   'timestamp': 1694127113845,
#   'candle_acc_trade_price': 265826.6873336,
#   'candle_acc_trade_volume': 0.29014897,
#   'prev_closing_price': 919580.0,
#   'change_price': 11660.0,
#   'change_rate': 0.0126797016},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-06T00:00:00',
#   'opening_price': 908520.0,
#   'high_price': 919580.0,
#   'low_price': 905000.0,
#   'trade_price': 919580.0,
#   'timestamp': 1694022970842,
#   'candle_acc_trade_price': 166256.5669196,
#   'candle_acc_trade_volume': 0.18129115,
#   'prev_closing_price': 909040.0,
#   'change_price': 10540.0,
#   'change_rate': 0.0115946493},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-05T00:00:00',
#   'opening_price': 905020.0,
#   'high_price': 912560.0,
#   'low_price': 905020.0,
#   'trade_price': 909040.0,
#   'timestamp': 1693918601096,
#   'candle_acc_trade_price': 15408.6572184,
#   'candle_acc_trade_volume': 0.01696389,
#   'prev_closing_price': 909360.0,
#   'change_price': -320.0,
#   'change_rate': -0.0003518958},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-04T00:00:00',
#   'opening_price': 910500.0,
#   'high_price': 916220.0,
#   'low_price': 901880.0,
#   'trade_price': 909360.0,
#   'timestamp': 1693866354766,
#   'candle_acc_trade_price': 350885.2747374,
#   'candle_acc_trade_volume': 0.38332919,
#   'prev_closing_price': 912460.0,
#   'change_price': -3100.0,
#   'change_rate': -0.0033974092},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-03T00:00:00',
#   'opening_price': 912860.0,
#   'high_price': 912860.0,
#   'low_price': 910500.0,
#   'trade_price': 912460.0,
#   'timestamp': 1693783850513,
#   'candle_acc_trade_price': 693841.6765008,
#   'candle_acc_trade_volume': 0.76092278,
#   'prev_closing_price': 902580.0,
#   'change_price': 9880.0,
#   'change_rate': 0.0109463981},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-02T00:00:00',
#   'opening_price': 911800.0,
#   'high_price': 915720.0,
#   'low_price': 902560.0,
#   'trade_price': 902580.0,
#   'timestamp': 1693680200694,
#   'candle_acc_trade_price': 1351913.8281124,
#   'candle_acc_trade_volume': 1.48639601,
#   'prev_closing_price': 910240.0,
#   'change_price': -7660.0,
#   'change_rate': -0.008415363},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-09-01T00:00:00',
#   'opening_price': 908920.0,
#   'high_price': 915540.0,
#   'low_price': 895500.0,
#   'trade_price': 910240.0,
#   'timestamp': 1693609940207,
#   'candle_acc_trade_price': 1339669.9182732,
#   'candle_acc_trade_volume': 1.47634875,
#   'prev_closing_price': 904340.0,
#   'change_price': 5900.0,
#   'change_rate': 0.0065240949},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-31T00:00:00',
#   'opening_price': 960080.0,
#   'high_price': 960080.0,
#   'low_price': 904340.0,
#   'trade_price': 904340.0,
#   'timestamp': 1693516146694,
#   'candle_acc_trade_price': 781631.5297082,
#   'candle_acc_trade_volume': 0.85449076,
#   'prev_closing_price': 948520.0,
#   'change_price': -44180.0,
#   'change_rate': -0.0465778265},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-30T00:00:00',
#   'opening_price': 971480.0,
#   'high_price': 971480.0,
#   'low_price': 947260.0,
#   'trade_price': 948520.0,
#   'timestamp': 1693431357260,
#   'candle_acc_trade_price': 131768.0945966,
#   'candle_acc_trade_volume': 0.13843037,
#   'prev_closing_price': 968200.0,
#   'change_price': -19680.0,
#   'change_rate': -0.0203263788},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-29T00:00:00',
#   'opening_price': 921080.0,
#   'high_price': 978360.0,
#   'low_price': 910000.0,
#   'trade_price': 968200.0,
#   'timestamp': 1693350570852,
#   'candle_acc_trade_price': 1058564.300869,
#   'candle_acc_trade_volume': 1.12361194,
#   'prev_closing_price': 921360.0,
#   'change_price': 46840.0,
#   'change_rate': 0.0508378918},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-28T00:00:00',
#   'opening_price': 914800.0,
#   'high_price': 921360.0,
#   'low_price': 914800.0,
#   'trade_price': 921360.0,
#   'timestamp': 1693235461724,
#   'candle_acc_trade_price': 53136.5612956,
#   'candle_acc_trade_volume': 0.05768277,
#   'prev_closing_price': 914800.0,
#   'change_price': 6560.0,
#   'change_rate': 0.0071709663},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-27T00:00:00',
#   'opening_price': 914800.0,
#   'high_price': 914800.0,
#   'low_price': 914800.0,
#   'trade_price': 914800.0,
#   'timestamp': 1693132447649,
#   'candle_acc_trade_price': 3075.072756,
#   'candle_acc_trade_volume': 0.00336147,
#   'prev_closing_price': 916800.0,
#   'change_price': -2000.0,
#   'change_rate': -0.0021815009},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-26T00:00:00',
#   'opening_price': 917960.0,
#   'high_price': 917960.0,
#   'low_price': 909240.0,
#   'trade_price': 916800.0,
#   'timestamp': 1693051909193,
#   'candle_acc_trade_price': 274444.9927402,
#   'candle_acc_trade_volume': 0.29969405,
#   'prev_closing_price': 919620.0,
#   'change_price': -2820.0,
#   'change_rate': -0.003066484},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-25T00:00:00',
#   'opening_price': 911200.0,
#   'high_price': 922440.0,
#   'low_price': 907020.0,
#   'trade_price': 919620.0,
#   'timestamp': 1692993097055,
#   'candle_acc_trade_price': 198221.4892448,
#   'candle_acc_trade_volume': 0.21653685,
#   'prev_closing_price': 922760.0,
#   'change_price': -3140.0,
#   'change_rate': -0.003402835},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-24T00:00:00',
#   'opening_price': 932320.0,
#   'high_price': 932320.0,
#   'low_price': 906680.0,
#   'trade_price': 922760.0,
#   'timestamp': 1692921429153,
#   'candle_acc_trade_price': 809370.7349034,
#   'candle_acc_trade_volume': 0.88027532,
#   'prev_closing_price': 933520.0,
#   'change_price': -10760.0,
#   'change_rate': -0.0115262662},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-23T00:00:00',
#   'opening_price': 920440.0,
#   'high_price': 933520.0,
#   'low_price': 905160.0,
#   'trade_price': 933520.0,
#   'timestamp': 1692819690558,
#   'candle_acc_trade_price': 279942.656553,
#   'candle_acc_trade_volume': 0.30524655,
#   'prev_closing_price': 900000.0,
#   'change_price': 33520.0,
#   'change_rate': 0.0372444444},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-22T00:00:00',
#   'opening_price': 918760.0,
#   'high_price': 918760.0,
#   'low_price': 900000.0,
#   'trade_price': 900000.0,
#   'timestamp': 1692742044009,
#   'candle_acc_trade_price': 261078.0733362,
#   'candle_acc_trade_volume': 0.28846141,
#   'prev_closing_price': 918900.0,
#   'change_price': -18900.0,
#   'change_rate': -0.0205680705},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-21T00:00:00',
#   'opening_price': 919680.0,
#   'high_price': 932420.0,
#   'low_price': 918900.0,
#   'trade_price': 918900.0,
#   'timestamp': 1692621865898,
#   'candle_acc_trade_price': 1017739.9770928,
#   'candle_acc_trade_volume': 1.1017697,
#   'prev_closing_price': 925000.0,
#   'change_price': -6100.0,
#   'change_rate': -0.0065945946},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-20T00:00:00',
#   'opening_price': 921060.0,
#   'high_price': 1035060.0,
#   'low_price': 914300.0,
#   'trade_price': 925000.0,
#   'timestamp': 1692544231200,
#   'candle_acc_trade_price': 763139.9958202,
#   'candle_acc_trade_volume': 0.82521358,
#   'prev_closing_price': 925980.0,
#   'change_price': -980.0,
#   'change_rate': -0.0010583382},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-19T00:00:00',
#   'opening_price': 927440.0,
#   'high_price': 927940.0,
#   'low_price': 910020.0,
#   'trade_price': 925980.0,
#   'timestamp': 1692468108374,
#   'candle_acc_trade_price': 1254580.166642,
#   'candle_acc_trade_volume': 1.36487762,
#   'prev_closing_price': 927440.0,
#   'change_price': -1460.0,
#   'change_rate': -0.0015742258},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-18T00:00:00',
#   'opening_price': 967000.0,
#   'high_price': 967000.0,
#   'low_price': 918460.0,
#   'trade_price': 927440.0,
#   'timestamp': 1692401844332,
#   'candle_acc_trade_price': 559315.0512928,
#   'candle_acc_trade_volume': 0.59881671,
#   'prev_closing_price': 967000.0,
#   'change_price': -39560.0,
#   'change_rate': -0.040910031},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-17T00:00:00',
#   'opening_price': 1020000.0,
#   'high_price': 1020000.0,
#   'low_price': 952500.0,
#   'trade_price': 967000.0,
#   'timestamp': 1692315627331,
#   'candle_acc_trade_price': 850891.8974848,
#   'candle_acc_trade_volume': 0.87195714,
#   'prev_closing_price': 1022000.0,
#   'change_price': -55000.0,
#   'change_rate': -0.053816047},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-16T00:00:00',
#   'opening_price': 1028040.0,
#   'high_price': 1038840.0,
#   'low_price': 1022000.0,
#   'trade_price': 1022000.0,
#   'timestamp': 1692230039828,
#   'candle_acc_trade_price': 783865.3016076,
#   'candle_acc_trade_volume': 0.76153311,
#   'prev_closing_price': 1035860.0,
#   'change_price': -13860.0,
#   'change_rate': -0.0133801865},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-15T00:00:00',
#   'opening_price': 1032020.0,
#   'high_price': 1040720.0,
#   'low_price': 1026140.0,
#   'trade_price': 1035860.0,
#   'timestamp': 1692127182205,
#   'candle_acc_trade_price': 308350.9092766,
#   'candle_acc_trade_volume': 0.29882591,
#   'prev_closing_price': 1032020.0,
#   'change_price': 3840.0,
#   'change_rate': 0.0037208581},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-14T00:00:00',
#   'opening_price': 1025900.0,
#   'high_price': 1036000.0,
#   'low_price': 1025900.0,
#   'trade_price': 1032020.0,
#   'timestamp': 1692048669777,
#   'candle_acc_trade_price': 396908.4018038,
#   'candle_acc_trade_volume': 0.38629297,
#   'prev_closing_price': 1033200.0,
#   'change_price': -1180.0,
#   'change_rate': -0.0011420828},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-13T00:00:00',
#   'opening_price': 1025440.0,
#   'high_price': 1033200.0,
#   'low_price': 1023820.0,
#   'trade_price': 1033200.0,
#   'timestamp': 1691950161172,
#   'candle_acc_trade_price': 56143.3216554,
#   'candle_acc_trade_volume': 0.05439334,
#   'prev_closing_price': 1024640.0,
#   'change_price': 8560.0,
#   'change_rate': 0.0083541537},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-12T00:00:00',
#   'opening_price': 1030280.0,
#   'high_price': 1030280.0,
#   'low_price': 1024460.0,
#   'trade_price': 1024640.0,
#   'timestamp': 1691847497762,
#   'candle_acc_trade_price': 123368.7250126,
#   'candle_acc_trade_volume': 0.12022385,
#   'prev_closing_price': 1023820.0,
#   'change_price': 820.0,
#   'change_rate': 0.000800922},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-11T00:00:00',
#   'opening_price': 1028000.0,
#   'high_price': 1033780.0,
#   'low_price': 1023820.0,
#   'trade_price': 1023820.0,
#   'timestamp': 1691755049271,
#   'candle_acc_trade_price': 7069.9959508,
#   'candle_acc_trade_volume': 0.00689312,
#   'prev_closing_price': 1034960.0,
#   'change_price': -11140.0,
#   'change_rate': -0.010763701},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-10T00:00:00',
#   'opening_price': 1031000.0,
#   'high_price': 1036660.0,
#   'low_price': 1030520.0,
#   'trade_price': 1034960.0,
#   'timestamp': 1691667469571,
#   'candle_acc_trade_price': 394513.7845998,
#   'candle_acc_trade_volume': 0.38129782,
#   'prev_closing_price': 1033440.0,
#   'change_price': 1520.0,
#   'change_rate': 0.0014708159},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-09T00:00:00',
#   'opening_price': 1039000.0,
#   'high_price': 1045000.0,
#   'low_price': 1030940.0,
#   'trade_price': 1033440.0,
#   'timestamp': 1691602154851,
#   'candle_acc_trade_price': 76822.2543962,
#   'candle_acc_trade_volume': 0.07430358,
#   'prev_closing_price': 1038000.0,
#   'change_price': -4560.0,
#   'change_rate': -0.0043930636},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-08T00:00:00',
#   'opening_price': 1011880.0,
#   'high_price': 1040000.0,
#   'low_price': 1011880.0,
#   'trade_price': 1038000.0,
#   'timestamp': 1691533299640,
#   'candle_acc_trade_price': 62825.127713,
#   'candle_acc_trade_volume': 0.06141439,
#   'prev_closing_price': 1011880.0,
#   'change_price': 26120.0,
#   'change_rate': 0.0258133375},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-07T00:00:00',
#   'opening_price': 1007500.0,
#   'high_price': 1012360.0,
#   'low_price': 1005000.0,
#   'trade_price': 1011880.0,
#   'timestamp': 1691443793275,
#   'candle_acc_trade_price': 120757.1379066,
#   'candle_acc_trade_volume': 0.11988068,
#   'prev_closing_price': 999020.0,
#   'change_price': 12860.0,
#   'change_rate': 0.0128726152},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-06T00:00:00',
#   'opening_price': 1005080.0,
#   'high_price': 1007780.0,
#   'low_price': 999000.0,
#   'trade_price': 999020.0,
#   'timestamp': 1691328099283,
#   'candle_acc_trade_price': 51679.392666,
#   'candle_acc_trade_volume': 0.05146186,
#   'prev_closing_price': 1007820.0,
#   'change_price': -8800.0,
#   'change_rate': -0.008731718},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-05T00:00:00',
#   'opening_price': 1009700.0,
#   'high_price': 1009700.0,
#   'low_price': 998100.0,
#   'trade_price': 1007820.0,
#   'timestamp': 1691270600237,
#   'candle_acc_trade_price': 78079.6770196,
#   'candle_acc_trade_volume': 0.07799208,
#   'prev_closing_price': 1001520.0,
#   'change_price': 6300.0,
#   'change_rate': 0.0062904385},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-04T00:00:00',
#   'opening_price': 1012920.0,
#   'high_price': 1012940.0,
#   'low_price': 999420.0,
#   'trade_price': 1001520.0,
#   'timestamp': 1691181929950,
#   'candle_acc_trade_price': 41796.0075944,
#   'candle_acc_trade_volume': 0.041483,
#   'prev_closing_price': 1012920.0,
#   'change_price': -11400.0,
#   'change_rate': -0.0112545907},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-03T00:00:00',
#   'opening_price': 1007480.0,
#   'high_price': 1012920.0,
#   'low_price': 998360.0,
#   'trade_price': 1012920.0,
#   'timestamp': 1691092502827,
#   'candle_acc_trade_price': 49828.8643344,
#   'candle_acc_trade_volume': 0.04984929,
#   'prev_closing_price': 999820.0,
#   'change_price': 13100.0,
#   'change_rate': 0.0131023584},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-02T00:00:00',
#   'opening_price': 1012340.0,
#   'high_price': 1024720.0,
#   'low_price': 999820.0,
#   'trade_price': 999820.0,
#   'timestamp': 1690995358111,
#   'candle_acc_trade_price': 406572.5439402,
#   'candle_acc_trade_volume': 0.40037992,
#   'prev_closing_price': 1012340.0,
#   'change_price': -12520.0,
#   'change_rate': -0.0123673865},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-08-01T00:00:00',
#   'opening_price': 998220.0,
#   'high_price': 1012340.0,
#   'low_price': 983220.0,
#   'trade_price': 1012340.0,
#   'timestamp': 1690934399167,
#   'candle_acc_trade_price': 487694.6947616,
#   'candle_acc_trade_volume': 0.48883725,
#   'prev_closing_price': 1002980.0,
#   'change_price': 9360.0,
#   'change_rate': 0.0093321901},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-31T00:00:00',
#   'opening_price': 1006760.0,
#   'high_price': 1009600.0,
#   'low_price': 1001920.0,
#   'trade_price': 1002980.0,
#   'timestamp': 1690825904262,
#   'candle_acc_trade_price': 61654.1605564,
#   'candle_acc_trade_volume': 0.0615284,
#   'prev_closing_price': 1001920.0,
#   'change_price': 1060.0,
#   'change_rate': 0.0010579687},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-30T00:00:00',
#   'opening_price': 999980.0,
#   'high_price': 1005700.0,
#   'low_price': 998200.0,
#   'trade_price': 1001920.0,
#   'timestamp': 1690748170578,
#   'candle_acc_trade_price': 209467.1547084,
#   'candle_acc_trade_volume': 0.20944147,
#   'prev_closing_price': 1003500.0,
#   'change_price': -1580.0,
#   'change_rate': -0.0015744893},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-29T00:00:00',
#   'opening_price': 1005460.0,
#   'high_price': 1006200.0,
#   'low_price': 999980.0,
#   'trade_price': 1003500.0,
#   'timestamp': 1690671453156,
#   'candle_acc_trade_price': 57588.649128,
#   'candle_acc_trade_volume': 0.0575525,
#   'prev_closing_price': 999980.0,
#   'change_price': 3520.0,
#   'change_rate': 0.0035200704},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-28T00:00:00',
#   'opening_price': 1010880.0,
#   'high_price': 1010880.0,
#   'low_price': 999980.0,
#   'trade_price': 999980.0,
#   'timestamp': 1690578341929,
#   'candle_acc_trade_price': 200032.0876084,
#   'candle_acc_trade_volume': 0.19890126,
#   'prev_closing_price': 1005000.0,
#   'change_price': -5020.0,
#   'change_rate': -0.0049950249},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-27T00:00:00',
#   'opening_price': 1010040.0,
#   'high_price': 1030000.0,
#   'low_price': 1000280.0,
#   'trade_price': 1005000.0,
#   'timestamp': 1690500708053,
#   'candle_acc_trade_price': 1590826.2836562,
#   'candle_acc_trade_volume': 1.57389859,
#   'prev_closing_price': 1006040.0,
#   'change_price': -1040.0,
#   'change_rate': -0.0010337561},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-26T00:00:00',
#   'opening_price': 1011900.0,
#   'high_price': 1011900.0,
#   'low_price': 998220.0,
#   'trade_price': 1006040.0,
#   'timestamp': 1690402835572,
#   'candle_acc_trade_price': 345965.7729462,
#   'candle_acc_trade_volume': 0.34355284,
#   'prev_closing_price': 1009540.0,
#   'change_price': -3500.0,
#   'change_rate': -0.0034669255},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-25T00:00:00',
#   'opening_price': 1014780.0,
#   'high_price': 1014900.0,
#   'low_price': 1001020.0,
#   'trade_price': 1009540.0,
#   'timestamp': 1690323825764,
#   'candle_acc_trade_price': 682389.3710448,
#   'candle_acc_trade_volume': 0.67268959,
#   'prev_closing_price': 1000000.0,
#   'change_price': 9540.0,
#   'change_rate': 0.00954},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-24T00:00:00',
#   'opening_price': 1027920.0,
#   'high_price': 1027920.0,
#   'low_price': 1000000.0,
#   'trade_price': 1000000.0,
#   'timestamp': 1690211511792,
#   'candle_acc_trade_price': 471360.5641356,
#   'candle_acc_trade_volume': 0.46555691,
#   'prev_closing_price': 1030000.0,
#   'change_price': -30000.0,
#   'change_rate': -0.0291262136},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-23T00:00:00',
#   'opening_price': 1029880.0,
#   'high_price': 1030000.0,
#   'low_price': 1020720.0,
#   'trade_price': 1030000.0,
#   'timestamp': 1690135161835,
#   'candle_acc_trade_price': 332642.054176,
#   'candle_acc_trade_volume': 0.32305613,
#   'prev_closing_price': 1016700.0,
#   'change_price': 13300.0,
#   'change_rate': 0.0130815383},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-22T00:00:00',
#   'opening_price': 1035440.0,
#   'high_price': 1035460.0,
#   'low_price': 1016100.0,
#   'trade_price': 1016700.0,
#   'timestamp': 1690068193939,
#   'candle_acc_trade_price': 49519.6628416,
#   'candle_acc_trade_volume': 0.04815094,
#   'prev_closing_price': 1031260.0,
#   'change_price': -14560.0,
#   'change_rate': -0.014118651},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-21T00:00:00',
#   'opening_price': 1019000.0,
#   'high_price': 1031260.0,
#   'low_price': 1016080.0,
#   'trade_price': 1031260.0,
#   'timestamp': 1689972397440,
#   'candle_acc_trade_price': 17955.8899614,
#   'candle_acc_trade_volume': 0.01761681,
#   'prev_closing_price': 1021600.0,
#   'change_price': 9660.0,
#   'change_rate': 0.0094557557},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-20T00:00:00',
#   'opening_price': 1019960.0,
#   'high_price': 1034020.0,
#   'low_price': 1019760.0,
#   'trade_price': 1021600.0,
#   'timestamp': 1689883680285,
#   'candle_acc_trade_price': 316323.413832,
#   'candle_acc_trade_volume': 0.30945399,
#   'prev_closing_price': 1019960.0,
#   'change_price': 1640.0,
#   'change_rate': 0.0016079062},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-19T00:00:00',
#   'opening_price': 1027620.0,
#   'high_price': 1034060.0,
#   'low_price': 1019960.0,
#   'trade_price': 1019960.0,
#   'timestamp': 1689791033749,
#   'candle_acc_trade_price': 27569.6570118,
#   'candle_acc_trade_volume': 0.02698066,
#   'prev_closing_price': 1019980.0,
#   'change_price': -20.0,
#   'change_rate': -1.96082e-05},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-18T00:00:00',
#   'opening_price': 1042620.0,
#   'high_price': 1042620.0,
#   'low_price': 1019960.0,
#   'trade_price': 1019980.0,
#   'timestamp': 1689722361418,
#   'candle_acc_trade_price': 186318.7087734,
#   'candle_acc_trade_volume': 0.18093971,
#   'prev_closing_price': 1033580.0,
#   'change_price': -13600.0,
#   'change_rate': -0.0131581493},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-17T00:00:00',
#   'opening_price': 1045020.0,
#   'high_price': 1048000.0,
#   'low_price': 1033580.0,
#   'trade_price': 1033580.0,
#   'timestamp': 1689619858142,
#   'candle_acc_trade_price': 105019.984258,
#   'candle_acc_trade_volume': 0.10068821,
#   'prev_closing_price': 1045000.0,
#   'change_price': -11420.0,
#   'change_rate': -0.0109282297},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-16T00:00:00',
#   'opening_price': 1046000.0,
#   'high_price': 1048000.0,
#   'low_price': 1043320.0,
#   'trade_price': 1045000.0,
#   'timestamp': 1689536502702,
#   'candle_acc_trade_price': 414540.2794498,
#   'candle_acc_trade_volume': 0.39637079,
#   'prev_closing_price': 1046000.0,
#   'change_price': -1000.0,
#   'change_rate': -0.0009560229},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-15T00:00:00',
#   'opening_price': 1051140.0,
#   'high_price': 1060280.0,
#   'low_price': 1046000.0,
#   'trade_price': 1046000.0,
#   'timestamp': 1689438919045,
#   'candle_acc_trade_price': 703144.1635546,
#   'candle_acc_trade_volume': 0.67001608,
#   'prev_closing_price': 1049060.0,
#   'change_price': -3060.0,
#   'change_rate': -0.002916897},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-14T00:00:00',
#   'opening_price': 1073220.0,
#   'high_price': 1087400.0,
#   'low_price': 1045820.0,
#   'trade_price': 1049060.0,
#   'timestamp': 1689360375854,
#   'candle_acc_trade_price': 700066.7188554,
#   'candle_acc_trade_volume': 0.65574149,
#   'prev_closing_price': 1071960.0,
#   'change_price': -22900.0,
#   'change_rate': -0.0213627374},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-13T00:00:00',
#   'opening_price': 1068720.0,
#   'high_price': 1080000.0,
#   'low_price': 1032440.0,
#   'trade_price': 1071960.0,
#   'timestamp': 1689291458796,
#   'candle_acc_trade_price': 689441.7375238,
#   'candle_acc_trade_volume': 0.64694252,
#   'prev_closing_price': 1059060.0,
#   'change_price': 12900.0,
#   'change_rate': 0.012180613},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-12T00:00:00',
#   'opening_price': 1060240.0,
#   'high_price': 1070000.0,
#   'low_price': 1059060.0,
#   'trade_price': 1059060.0,
#   'timestamp': 1689191148241,
#   'candle_acc_trade_price': 307063.716854,
#   'candle_acc_trade_volume': 0.28945289,
#   'prev_closing_price': 1067220.0,
#   'change_price': -8160.0,
#   'change_rate': -0.0076460336},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-11T00:00:00',
#   'opening_price': 1069980.0,
#   'high_price': 1069980.0,
#   'low_price': 1060240.0,
#   'trade_price': 1067220.0,
#   'timestamp': 1689090693056,
#   'candle_acc_trade_price': 125623.2516016,
#   'candle_acc_trade_volume': 0.1179256,
#   'prev_closing_price': 1061360.0,
#   'change_price': 5860.0,
#   'change_rate': 0.0055212181},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-10T00:00:00',
#   'opening_price': 1060240.0,
#   'high_price': 1076440.0,
#   'low_price': 1059340.0,
#   'trade_price': 1061360.0,
#   'timestamp': 1689026150601,
#   'candle_acc_trade_price': 644961.8413386,
#   'candle_acc_trade_volume': 0.6081489,
#   'prev_closing_price': 1064580.0,
#   'change_price': -3220.0,
#   'change_rate': -0.003024667},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-09T00:00:00',
#   'opening_price': 1060240.0,
#   'high_price': 1064580.0,
#   'low_price': 1060240.0,
#   'trade_price': 1064580.0,
#   'timestamp': 1688913391154,
#   'candle_acc_trade_price': 96783.166116,
#   'candle_acc_trade_volume': 0.09107809,
#   'prev_closing_price': 1060240.0,
#   'change_price': 4340.0,
#   'change_rate': 0.0040934128},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-08T00:00:00',
#   'opening_price': 1064040.0,
#   'high_price': 1064040.0,
#   'low_price': 1060240.0,
#   'trade_price': 1060240.0,
#   'timestamp': 1688844249512,
#   'candle_acc_trade_price': 387422.1525694,
#   'candle_acc_trade_volume': 0.36540407,
#   'prev_closing_price': 1068880.0,
#   'change_price': -8640.0,
#   'change_rate': -0.0080832273},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-07T00:00:00',
#   'opening_price': 1053400.0,
#   'high_price': 1068980.0,
#   'low_price': 1051180.0,
#   'trade_price': 1068880.0,
#   'timestamp': 1688766763975,
#   'candle_acc_trade_price': 294020.5881184,
#   'candle_acc_trade_volume': 0.27936703,
#   'prev_closing_price': 1065980.0,
#   'change_price': 2900.0,
#   'change_rate': 0.0027205013},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-06T00:00:00',
#   'opening_price': 1065000.0,
#   'high_price': 1101320.0,
#   'low_price': 1054900.0,
#   'trade_price': 1065980.0,
#   'timestamp': 1688686548830,
#   'candle_acc_trade_price': 1119030.8274894,
#   'candle_acc_trade_volume': 1.03334718,
#   'prev_closing_price': 1060000.0,
#   'change_price': 5980.0,
#   'change_rate': 0.0056415094},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-05T00:00:00',
#   'opening_price': 1071340.0,
#   'high_price': 1071340.0,
#   'low_price': 1055700.0,
#   'trade_price': 1060000.0,
#   'timestamp': 1688570293542,
#   'candle_acc_trade_price': 463516.2149008,
#   'candle_acc_trade_volume': 0.43560126,
#   'prev_closing_price': 1071320.0,
#   'change_price': -11320.0,
#   'change_rate': -0.0105664041},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-04T00:00:00',
#   'opening_price': 1090480.0,
#   'high_price': 1092620.0,
#   'low_price': 1071320.0,
#   'trade_price': 1071320.0,
#   'timestamp': 1688499081979,
#   'candle_acc_trade_price': 297489.1116786,
#   'candle_acc_trade_volume': 0.27420092,
#   'prev_closing_price': 1090480.0,
#   'change_price': -19160.0,
#   'change_rate': -0.0175702443},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-03T00:00:00',
#   'opening_price': 1078660.0,
#   'high_price': 1090760.0,
#   'low_price': 1071220.0,
#   'trade_price': 1090480.0,
#   'timestamp': 1688414085014,
#   'candle_acc_trade_price': 45523.9629284,
#   'candle_acc_trade_volume': 0.04186144,
#   'prev_closing_price': 1078440.0,
#   'change_price': 12040.0,
#   'change_rate': 0.0111642743},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-02T00:00:00',
#   'opening_price': 1069480.0,
#   'high_price': 1082060.0,
#   'low_price': 1064460.0,
#   'trade_price': 1078440.0,
#   'timestamp': 1688337810168,
#   'candle_acc_trade_price': 483595.5184406,
#   'candle_acc_trade_volume': 0.45058584,
#   'prev_closing_price': 1066340.0,
#   'change_price': 12100.0,
#   'change_rate': 0.0113472251},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-07-01T00:00:00',
#   'opening_price': 1078100.0,
#   'high_price': 1079360.0,
#   'low_price': 1057000.0,
#   'trade_price': 1066340.0,
#   'timestamp': 1688229319442,
#   'candle_acc_trade_price': 783611.4140768,
#   'candle_acc_trade_volume': 0.72949823,
#   'prev_closing_price': 1077920.0,
#   'change_price': -11580.0,
#   'change_rate': -0.0107429123},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-30T00:00:00',
#   'opening_price': 1077180.0,
#   'high_price': 1095000.0,
#   'low_price': 1048000.0,
#   'trade_price': 1077920.0,
#   'timestamp': 1688169528941,
#   'candle_acc_trade_price': 893287.21312,
#   'candle_acc_trade_volume': 0.82912684,
#   'prev_closing_price': 1077180.0,
#   'change_price': 740.0,
#   'change_rate': 0.000686979},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-29T00:00:00',
#   'opening_price': 1074600.0,
#   'high_price': 1096200.0,
#   'low_price': 1073580.0,
#   'trade_price': 1077180.0,
#   'timestamp': 1688082077953,
#   'candle_acc_trade_price': 252334.2290106,
#   'candle_acc_trade_volume': 0.2335736,
#   'prev_closing_price': 1074620.0,
#   'change_price': 2560.0,
#   'change_rate': 0.0023822374},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-28T00:00:00',
#   'opening_price': 1069780.0,
#   'high_price': 1080420.0,
#   'low_price': 1060020.0,
#   'trade_price': 1074620.0,
#   'timestamp': 1687984848866,
#   'candle_acc_trade_price': 136994.1200518,
#   'candle_acc_trade_volume': 0.12715053,
#   'prev_closing_price': 1069780.0,
#   'change_price': 4840.0,
#   'change_rate': 0.0045242947},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-27T00:00:00',
#   'opening_price': 1061580.0,
#   'high_price': 1084400.0,
#   'low_price': 1057640.0,
#   'trade_price': 1069780.0,
#   'timestamp': 1687909623694,
#   'candle_acc_trade_price': 570785.7903724,
#   'candle_acc_trade_volume': 0.53671344,
#   'prev_closing_price': 1057640.0,
#   'change_price': 12140.0,
#   'change_rate': 0.0114783858},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-26T00:00:00',
#   'opening_price': 1067260.0,
#   'high_price': 1073060.0,
#   'low_price': 1054120.0,
#   'trade_price': 1057640.0,
#   'timestamp': 1687819723588,
#   'candle_acc_trade_price': 481850.227455,
#   'candle_acc_trade_volume': 0.45358773,
#   'prev_closing_price': 1067260.0,
#   'change_price': -9620.0,
#   'change_rate': -0.0090137361},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-25T00:00:00',
#   'opening_price': 1060720.0,
#   'high_price': 1078740.0,
#   'low_price': 1060160.0,
#   'trade_price': 1067260.0,
#   'timestamp': 1687734139379,
#   'candle_acc_trade_price': 433130.0533864,
#   'candle_acc_trade_volume': 0.40631826,
#   'prev_closing_price': 1070000.0,
#   'change_price': -2740.0,
#   'change_rate': -0.0025607477},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-24T00:00:00',
#   'opening_price': 1075000.0,
#   'high_price': 1083400.0,
#   'low_price': 1055220.0,
#   'trade_price': 1070000.0,
#   'timestamp': 1687637899538,
#   'candle_acc_trade_price': 757205.555888,
#   'candle_acc_trade_volume': 0.70417537,
#   'prev_closing_price': 1073000.0,
#   'change_price': -3000.0,
#   'change_rate': -0.0027958993},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-23T00:00:00',
#   'opening_price': 1043260.0,
#   'high_price': 1086620.0,
#   'low_price': 1042740.0,
#   'trade_price': 1073000.0,
#   'timestamp': 1687564528134,
#   'candle_acc_trade_price': 210843.08732,
#   'candle_acc_trade_volume': 0.19938852,
#   'prev_closing_price': 1043260.0,
#   'change_price': 29740.0,
#   'change_rate': 0.028506796},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-22T00:00:00',
#   'opening_price': 1032140.0,
#   'high_price': 1050000.0,
#   'low_price': 1032120.0,
#   'trade_price': 1043260.0,
#   'timestamp': 1687475911253,
#   'candle_acc_trade_price': 224103.7842078,
#   'candle_acc_trade_volume': 0.21498278,
#   'prev_closing_price': 1032120.0,
#   'change_price': 11140.0,
#   'change_rate': 0.0107933186},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-21T00:00:00',
#   'opening_price': 970000.0,
#   'high_price': 1040480.0,
#   'low_price': 968760.0,
#   'trade_price': 1032120.0,
#   'timestamp': 1687383417389,
#   'candle_acc_trade_price': 508236.3930536,
#   'candle_acc_trade_volume': 0.50689212,
#   'prev_closing_price': 968000.0,
#   'change_price': 64120.0,
#   'change_rate': 0.0662396694},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-20T00:00:00',
#   'opening_price': 925900.0,
#   'high_price': 968000.0,
#   'low_price': 925900.0,
#   'trade_price': 968000.0,
#   'timestamp': 1687305075674,
#   'candle_acc_trade_price': 117143.4632292,
#   'candle_acc_trade_volume': 0.12532394,
#   'prev_closing_price': 929840.0,
#   'change_price': 38160.0,
#   'change_rate': 0.0410393186},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-19T00:00:00',
#   'opening_price': 907860.0,
#   'high_price': 929880.0,
#   'low_price': 886440.0,
#   'trade_price': 929840.0,
#   'timestamp': 1687198200614,
#   'candle_acc_trade_price': 360340.3288906,
#   'candle_acc_trade_volume': 0.39000923,
#   'prev_closing_price': 911840.0,
#   'change_price': 18000.0,
#   'change_rate': 0.0197403053},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-18T00:00:00',
#   'opening_price': 917320.0,
#   'high_price': 917320.0,
#   'low_price': 906740.0,
#   'trade_price': 911840.0,
#   'timestamp': 1687106606310,
#   'candle_acc_trade_price': 57382.1044956,
#   'candle_acc_trade_volume': 0.06302515,
#   'prev_closing_price': 916640.0,
#   'change_price': -4800.0,
#   'change_rate': -0.005236516},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-17T00:00:00',
#   'opening_price': 900820.0,
#   'high_price': 916640.0,
#   'low_price': 900820.0,
#   'trade_price': 916640.0,
#   'timestamp': 1686980507797,
#   'candle_acc_trade_price': 103722.9809118,
#   'candle_acc_trade_volume': 0.11329993,
#   'prev_closing_price': 911080.0,
#   'change_price': 5560.0,
#   'change_rate': 0.0061026474},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-16T00:00:00',
#   'opening_price': 882660.0,
#   'high_price': 915880.0,
#   'low_price': 882660.0,
#   'trade_price': 911080.0,
#   'timestamp': 1686952601942,
#   'candle_acc_trade_price': 41541.9046638,
#   'candle_acc_trade_volume': 0.04667678,
#   'prev_closing_price': 885320.0,
#   'change_price': 25760.0,
#   'change_rate': 0.0290968237},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-15T00:00:00',
#   'opening_price': 880380.0,
#   'high_price': 885320.0,
#   'low_price': 865060.0,
#   'trade_price': 885320.0,
#   'timestamp': 1686862935159,
#   'candle_acc_trade_price': 183033.119527,
#   'candle_acc_trade_volume': 0.20909612,
#   'prev_closing_price': 875500.0,
#   'change_price': 9820.0,
#   'change_rate': 0.0112164477},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-14T00:00:00',
#   'opening_price': 897260.0,
#   'high_price': 902400.0,
#   'low_price': 875000.0,
#   'trade_price': 875500.0,
#   'timestamp': 1686784292884,
#   'candle_acc_trade_price': 281737.9325816,
#   'candle_acc_trade_volume': 0.31694911,
#   'prev_closing_price': 897260.0,
#   'change_price': -21760.0,
#   'change_rate': -0.0242516105},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-13T00:00:00',
#   'opening_price': 899780.0,
#   'high_price': 911060.0,
#   'low_price': 897020.0,
#   'trade_price': 897260.0,
#   'timestamp': 1686670038138,
#   'candle_acc_trade_price': 168398.9134882,
#   'candle_acc_trade_volume': 0.18592968,
#   'prev_closing_price': 897800.0,
#   'change_price': -540.0,
#   'change_rate': -0.0006014703},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-12T00:00:00',
#   'opening_price': 892660.0,
#   'high_price': 899540.0,
#   'low_price': 892660.0,
#   'trade_price': 897800.0,
#   'timestamp': 1686614056090,
#   'candle_acc_trade_price': 86040.6332424,
#   'candle_acc_trade_volume': 0.09603974,
#   'prev_closing_price': 916060.0,
#   'change_price': -18260.0,
#   'change_rate': -0.0199331921},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-11T00:00:00',
#   'opening_price': 916060.0,
#   'high_price': 916060.0,
#   'low_price': 916060.0,
#   'trade_price': 916060.0,
#   'timestamp': 1686515033481,
#   'candle_acc_trade_price': 1598.5613424,
#   'candle_acc_trade_volume': 0.00174504,
#   'prev_closing_price': 900660.0,
#   'change_price': 15400.0,
#   'change_rate': 0.0170985722},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-10T00:00:00',
#   'opening_price': 915160.0,
#   'high_price': 915160.0,
#   'low_price': 892000.0,
#   'trade_price': 900660.0,
#   'timestamp': 1686436074589,
#   'candle_acc_trade_price': 227571.451548,
#   'candle_acc_trade_volume': 0.25128119,
#   'prev_closing_price': 912140.0,
#   'change_price': -11480.0,
#   'change_rate': -0.0125857873},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-09T00:00:00',
#   'opening_price': 917280.0,
#   'high_price': 920620.0,
#   'low_price': 912140.0,
#   'trade_price': 912140.0,
#   'timestamp': 1686350065470,
#   'candle_acc_trade_price': 77044.6678818,
#   'candle_acc_trade_volume': 0.08398952,
#   'prev_closing_price': 917300.0,
#   'change_price': -5160.0,
#   'change_rate': -0.0056252044},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-08T00:00:00',
#   'opening_price': 919720.0,
#   'high_price': 926980.0,
#   'low_price': 910900.0,
#   'trade_price': 917300.0,
#   'timestamp': 1686262382314,
#   'candle_acc_trade_price': 65935.257815,
#   'candle_acc_trade_volume': 0.07176014,
#   'prev_closing_price': 910000.0,
#   'change_price': 7300.0,
#   'change_rate': 0.008021978},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-07T00:00:00',
#   'opening_price': 933300.0,
#   'high_price': 942920.0,
#   'low_price': 910000.0,
#   'trade_price': 910000.0,
#   'timestamp': 1686175087993,
#   'candle_acc_trade_price': 154280.6893282,
#   'candle_acc_trade_volume': 0.16585266,
#   'prev_closing_price': 930840.0,
#   'change_price': -20840.0,
#   'change_rate': -0.0223883804},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-06T00:00:00',
#   'opening_price': 904580.0,
#   'high_price': 943220.0,
#   'low_price': 888000.0,
#   'trade_price': 930840.0,
#   'timestamp': 1686094901426,
#   'candle_acc_trade_price': 1113578.2245514,
#   'candle_acc_trade_volume': 1.22244117,
#   'prev_closing_price': 904720.0,
#   'change_price': 26120.0,
#   'change_rate': 0.0288708109},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-05T00:00:00',
#   'opening_price': 937420.0,
#   'high_price': 940620.0,
#   'low_price': 890000.0,
#   'trade_price': 904720.0,
#   'timestamp': 1686008374484,
#   'candle_acc_trade_price': 219923.5680312,
#   'candle_acc_trade_volume': 0.2422376,
#   'prev_closing_price': 947140.0,
#   'change_price': -42420.0,
#   'change_rate': -0.0447874654},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-04T00:00:00',
#   'opening_price': 935300.0,
#   'high_price': 947140.0,
#   'low_price': 935300.0,
#   'trade_price': 947140.0,
#   'timestamp': 1685917056093,
#   'candle_acc_trade_price': 9967.0631202,
#   'candle_acc_trade_volume': 0.01059796,
#   'prev_closing_price': 932340.0,
#   'change_price': 14800.0,
#   'change_rate': 0.0158740374},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-03T00:00:00',
#   'opening_price': 946200.0,
#   'high_price': 946200.0,
#   'low_price': 932340.0,
#   'trade_price': 932340.0,
#   'timestamp': 1685823406627,
#   'candle_acc_trade_price': 39071.2206834,
#   'candle_acc_trade_volume': 0.04162235,
#   'prev_closing_price': 946360.0,
#   'change_price': -14020.0,
#   'change_rate': -0.0148146583},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-02T00:00:00',
#   'opening_price': 928000.0,
#   'high_price': 946360.0,
#   'low_price': 924660.0,
#   'trade_price': 946360.0,
#   'timestamp': 1685747544388,
#   'candle_acc_trade_price': 81515.0373652,
#   'candle_acc_trade_volume': 0.08750684,
#   'prev_closing_price': 928000.0,
#   'change_price': 18360.0,
#   'change_rate': 0.0197844828},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-06-01T00:00:00',
#   'opening_price': 944700.0,
#   'high_price': 952260.0,
#   'low_price': 928000.0,
#   'trade_price': 928000.0,
#   'timestamp': 1685648051553,
#   'candle_acc_trade_price': 4179621.5367818,
#   'candle_acc_trade_volume': 4.4441317,
#   'prev_closing_price': 937160.0,
#   'change_price': -9160.0,
#   'change_rate': -0.0097742114},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-31T00:00:00',
#   'opening_price': 961880.0,
#   'high_price': 961880.0,
#   'low_price': 927980.0,
#   'trade_price': 937160.0,
#   'timestamp': 1685575065200,
#   'candle_acc_trade_price': 2262081.3630508,
#   'candle_acc_trade_volume': 2.38713255,
#   'prev_closing_price': 955000.0,
#   'change_price': -17840.0,
#   'change_rate': -0.0186806283},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-30T00:00:00',
#   'opening_price': 960400.0,
#   'high_price': 975040.0,
#   'low_price': 955000.0,
#   'trade_price': 955000.0,
#   'timestamp': 1685483750418,
#   'candle_acc_trade_price': 3936229.2475482,
#   'candle_acc_trade_volume': 4.06873663,
#   'prev_closing_price': 960200.0,
#   'change_price': -5200.0,
#   'change_rate': -0.0054155384},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-29T00:00:00',
#   'opening_price': 968240.0,
#   'high_price': 973140.0,
#   'low_price': 960000.0,
#   'trade_price': 960200.0,
#   'timestamp': 1685391539960,
#   'candle_acc_trade_price': 1011919.810112,
#   'candle_acc_trade_volume': 1.04241508,
#   'prev_closing_price': 953860.0,
#   'change_price': 6340.0,
#   'change_rate': 0.0066466777},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-28T00:00:00',
#   'opening_price': 928000.0,
#   'high_price': 974580.0,
#   'low_price': 928000.0,
#   'trade_price': 953860.0,
#   'timestamp': 1685318158253,
#   'candle_acc_trade_price': 888939.8426398,
#   'candle_acc_trade_volume': 0.94592377,
#   'prev_closing_price': 925360.0,
#   'change_price': 28500.0,
#   'change_rate': 0.0307988242},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-27T00:00:00',
#   'opening_price': 929320.0,
#   'high_price': 930480.0,
#   'low_price': 921000.0,
#   'trade_price': 925360.0,
#   'timestamp': 1685220054847,
#   'candle_acc_trade_price': 1039117.3213462,
#   'candle_acc_trade_volume': 1.12013508,
#   'prev_closing_price': 928840.0,
#   'change_price': -3480.0,
#   'change_rate': -0.0037466087},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-26T00:00:00',
#   'opening_price': 914920.0,
#   'high_price': 928840.0,
#   'low_price': 911360.0,
#   'trade_price': 928840.0,
#   'timestamp': 1685140456877,
#   'candle_acc_trade_price': 358954.5533204,
#   'candle_acc_trade_volume': 0.39081652,
#   'prev_closing_price': 911520.0,
#   'change_price': 17320.0,
#   'change_rate': 0.0190012287},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-25T00:00:00',
#   'opening_price': 913840.0,
#   'high_price': 918920.0,
#   'low_price': 901480.0,
#   'trade_price': 911520.0,
#   'timestamp': 1685049658433,
#   'candle_acc_trade_price': 1251650.0656976,
#   'candle_acc_trade_volume': 1.37418111,
#   'prev_closing_price': 907500.0,
#   'change_price': 4020.0,
#   'change_rate': 0.0044297521},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-24T00:00:00',
#   'opening_price': 931620.0,
#   'high_price': 931620.0,
#   'low_price': 907500.0,
#   'trade_price': 907500.0,
#   'timestamp': 1684936351854,
#   'candle_acc_trade_price': 562347.2505284,
#   'candle_acc_trade_volume': 0.61468404,
#   'prev_closing_price': 935520.0,
#   'change_price': -28020.0,
#   'change_rate': -0.0299512571},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-23T00:00:00',
#   'opening_price': 930000.0,
#   'high_price': 940000.0,
#   'low_price': 930000.0,
#   'trade_price': 935520.0,
#   'timestamp': 1684881757633,
#   'candle_acc_trade_price': 80201.21821,
#   'candle_acc_trade_volume': 0.08573515,
#   'prev_closing_price': 912680.0,
#   'change_price': 22840.0,
#   'change_rate': 0.0250252005},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-22T00:00:00',
#   'opening_price': 912000.0,
#   'high_price': 913280.0,
#   'low_price': 912000.0,
#   'trade_price': 912680.0,
#   'timestamp': 1684759123267,
#   'candle_acc_trade_price': 8450.5465644,
#   'candle_acc_trade_volume': 0.00926433,
#   'prev_closing_price': 915000.0,
#   'change_price': -2320.0,
#   'change_rate': -0.0025355191},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-21T00:00:00',
#   'opening_price': 925000.0,
#   'high_price': 925340.0,
#   'low_price': 915000.0,
#   'trade_price': 915000.0,
#   'timestamp': 1684693872180,
#   'candle_acc_trade_price': 15630.2676936,
#   'candle_acc_trade_volume': 0.01695878,
#   'prev_closing_price': 913820.0,
#   'change_price': 1180.0,
#   'change_rate': 0.0012912827},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-20T00:00:00',
#   'opening_price': 923340.0,
#   'high_price': 923340.0,
#   'low_price': 913820.0,
#   'trade_price': 913820.0,
#   'timestamp': 1684588032791,
#   'candle_acc_trade_price': 25914.3831148,
#   'candle_acc_trade_volume': 0.02811478,
#   'prev_closing_price': 924820.0,
#   'change_price': -11000.0,
#   'change_rate': -0.0118942064},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-19T00:00:00',
#   'opening_price': 925000.0,
#   'high_price': 926820.0,
#   'low_price': 924820.0,
#   'trade_price': 924820.0,
#   'timestamp': 1684497841118,
#   'candle_acc_trade_price': 4508.9651276,
#   'candle_acc_trade_volume': 0.0048734,
#   'prev_closing_price': 910000.0,
#   'change_price': 14820.0,
#   'change_rate': 0.0162857143},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-18T00:00:00',
#   'opening_price': 926840.0,
#   'high_price': 931900.0,
#   'low_price': 910000.0,
#   'trade_price': 910000.0,
#   'timestamp': 1684432678275,
#   'candle_acc_trade_price': 21259.30513,
#   'candle_acc_trade_volume': 0.02295407,
#   'prev_closing_price': 925000.0,
#   'change_price': -15000.0,
#   'change_rate': -0.0162162162},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-17T00:00:00',
#   'opening_price': 922220.0,
#   'high_price': 925100.0,
#   'low_price': 910000.0,
#   'trade_price': 925000.0,
#   'timestamp': 1684351042419,
#   'candle_acc_trade_price': 36607.948825,
#   'candle_acc_trade_volume': 0.04003252,
#   'prev_closing_price': 915240.0,
#   'change_price': 9760.0,
#   'change_rate': 0.0106638696},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-16T00:00:00',
#   'opening_price': 910000.0,
#   'high_price': 917060.0,
#   'low_price': 910000.0,
#   'trade_price': 915240.0,
#   'timestamp': 1684269446022,
#   'candle_acc_trade_price': 32153.3110906,
#   'candle_acc_trade_volume': 0.03509191,
#   'prev_closing_price': 925000.0,
#   'change_price': -9760.0,
#   'change_rate': -0.0105513514},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-15T00:00:00',
#   'opening_price': 903000.0,
#   'high_price': 925000.0,
#   'low_price': 899080.0,
#   'trade_price': 925000.0,
#   'timestamp': 1684170734139,
#   'candle_acc_trade_price': 31087.6587762,
#   'candle_acc_trade_volume': 0.0344222,
#   'prev_closing_price': 904220.0,
#   'change_price': 20780.0,
#   'change_rate': 0.0229811329},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-14T00:00:00',
#   'opening_price': 902460.0,
#   'high_price': 916420.0,
#   'low_price': 902460.0,
#   'trade_price': 904220.0,
#   'timestamp': 1684089228610,
#   'candle_acc_trade_price': 435737.546077,
#   'candle_acc_trade_volume': 0.47908141,
#   'prev_closing_price': 901940.0,
#   'change_price': 2280.0,
#   'change_rate': 0.0025278843},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-13T00:00:00',
#   'opening_price': 905900.0,
#   'high_price': 905900.0,
#   'low_price': 901940.0,
#   'trade_price': 901940.0,
#   'timestamp': 1683986034369,
#   'candle_acc_trade_price': 151047.091788,
#   'candle_acc_trade_volume': 0.16677394,
#   'prev_closing_price': 891100.0,
#   'change_price': 10840.0,
#   'change_rate': 0.0121647402},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-12T00:00:00',
#   'opening_price': 902000.0,
#   'high_price': 902000.0,
#   'low_price': 880000.0,
#   'trade_price': 891100.0,
#   'timestamp': 1683920890420,
#   'candle_acc_trade_price': 814911.334042,
#   'candle_acc_trade_volume': 0.91763639,
#   'prev_closing_price': 912160.0,
#   'change_price': -21060.0,
#   'change_rate': -0.0230880547},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-11T00:00:00',
#   'opening_price': 925200.0,
#   'high_price': 933600.0,
#   'low_price': 906680.0,
#   'trade_price': 912160.0,
#   'timestamp': 1683848528894,
#   'candle_acc_trade_price': 1388991.2762592,
#   'candle_acc_trade_volume': 1.51675795,
#   'prev_closing_price': 926720.0,
#   'change_price': -14560.0,
#   'change_rate': -0.015711326},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-05-10T00:00:00',
#   'opening_price': 934320.0,
#   'high_price': 951040.0,
#   'low_price': 919740.0,
# ...
#   'candle_acc_trade_volume': 0.03839991,
#   'prev_closing_price': 955020.0,
#   'change_price': 4980.0,
#   'change_rate': 0.0052145505},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-04-04T00:00:00',
#   'opening_price': 953500.0,
#   'high_price': 969020.0,
#   'low_price': 952560.0,
#   'trade_price': 955020.0,
#   'timestamp': 1680644903039,
#   'candle_acc_trade_price': 27962.2635686,
#   'candle_acc_trade_volume': 0.02913085,
#   'prev_closing_price': 954000.0,
#   'change_price': 1020.0,
#   'change_rate': 0.0010691824},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-04-03T00:00:00',
#   'opening_price': 965500.0,
#   'high_price': 975000.0,
#   'low_price': 936480.0,
#   'trade_price': 954000.0,
#   'timestamp': 1680566014358,
#   'candle_acc_trade_price': 816363.0509932,
#   'candle_acc_trade_volume': 0.85239083,
#   'prev_closing_price': 965500.0,
#   'change_price': -11500.0,
#   'change_rate': -0.011910927},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-04-02T00:00:00',
#   'opening_price': 975000.0,
#   'high_price': 975000.0,
#   'low_price': 959240.0,
#   'trade_price': 965500.0,
#   'timestamp': 1680477542344,
#   'candle_acc_trade_price': 53014.7581706,
#   'candle_acc_trade_volume': 0.05498348,
#   'prev_closing_price': 975860.0,
#   'change_price': -10360.0,
#   'change_rate': -0.0106162769},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-04-01T00:00:00',
#   'opening_price': 975000.0,
#   'high_price': 976480.0,
#   'low_price': 963380.0,
#   'trade_price': 975860.0,
#   'timestamp': 1680392564343,
#   'candle_acc_trade_price': 171652.2673304,
#   'candle_acc_trade_volume': 0.17651425,
#   'prev_closing_price': 975000.0,
#   'change_price': 860.0,
#   'change_rate': 0.0008820513},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-31T00:00:00',
#   'opening_price': 963020.0,
#   'high_price': 977580.0,
#   'low_price': 942820.0,
#   'trade_price': 975000.0,
#   'timestamp': 1680306060419,
#   'candle_acc_trade_price': 249916.300763,
#   'candle_acc_trade_volume': 0.26043145,
#   'prev_closing_price': 962120.0,
#   'change_price': 12880.0,
#   'change_rate': 0.0133871035},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-30T00:00:00',
#   'opening_price': 972240.0,
#   'high_price': 993520.0,
#   'low_price': 950000.0,
#   'trade_price': 962120.0,
#   'timestamp': 1680219991412,
#   'candle_acc_trade_price': 2095601.191045,
#   'candle_acc_trade_volume': 2.15890694,
#   'prev_closing_price': 968500.0,
#   'change_price': -6380.0,
#   'change_rate': -0.0065875065},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-29T00:00:00',
#   'opening_price': 933460.0,
#   'high_price': 975360.0,
#   'low_price': 933460.0,
#   'trade_price': 968500.0,
#   'timestamp': 1680110625908,
#   'candle_acc_trade_price': 531815.2451658,
#   'candle_acc_trade_volume': 0.55414281,
#   'prev_closing_price': 933460.0,
#   'change_price': 35040.0,
#   'change_rate': 0.0375377627},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-28T00:00:00',
#   'opening_price': 933940.0,
#   'high_price': 933960.0,
#   'low_price': 916400.0,
#   'trade_price': 933460.0,
#   'timestamp': 1680035177689,
#   'candle_acc_trade_price': 308454.0625178,
#   'candle_acc_trade_volume': 0.33225075,
#   'prev_closing_price': 937440.0,
#   'change_price': -3980.0,
#   'change_rate': -0.0042456051},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-27T00:00:00',
#   'opening_price': 956840.0,
#   'high_price': 960680.0,
#   'low_price': 925000.0,
#   'trade_price': 937440.0,
#   'timestamp': 1679961520512,
#   'candle_acc_trade_price': 53879.291119,
#   'candle_acc_trade_volume': 0.05730885,
#   'prev_closing_price': 956820.0,
#   'change_price': -19380.0,
#   'change_rate': -0.0202545933},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-26T00:00:00',
#   'opening_price': 951740.0,
#   'high_price': 960000.0,
#   'low_price': 951740.0,
#   'trade_price': 956820.0,
#   'timestamp': 1679862837374,
#   'candle_acc_trade_price': 7913.4828932,
#   'candle_acc_trade_volume': 0.00828277,
#   'prev_closing_price': 937760.0,
#   'change_price': 19060.0,
#   'change_rate': 0.0203250299},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-25T00:00:00',
#   'opening_price': 944400.0,
#   'high_price': 953940.0,
#   'low_price': 937100.0,
#   'trade_price': 937760.0,
#   'timestamp': 1679778313401,
#   'candle_acc_trade_price': 124224.9349124,
#   'candle_acc_trade_volume': 0.13126348,
#   'prev_closing_price': 937100.0,
#   'change_price': 660.0,
#   'change_rate': 0.0007043005},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-24T00:00:00',
#   'opening_price': 962000.0,
#   'high_price': 985460.0,
#   'low_price': 937100.0,
#   'trade_price': 937100.0,
#   'timestamp': 1679692865330,
#   'candle_acc_trade_price': 1210757.6939138,
#   'candle_acc_trade_volume': 1.25252744,
#   'prev_closing_price': 972860.0,
#   'change_price': -35760.0,
#   'change_rate': -0.0367576013},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-23T00:00:00',
#   'opening_price': 938000.0,
#   'high_price': 982780.0,
#   'low_price': 935320.0,
#   'trade_price': 972860.0,
#   'timestamp': 1679614278109,
#   'candle_acc_trade_price': 1646938.8781598,
#   'candle_acc_trade_volume': 1.71328274,
#   'prev_closing_price': 940440.0,
#   'change_price': 32420.0,
#   'change_rate': 0.0344732253},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-22T00:00:00',
#   'opening_price': 962500.0,
#   'high_price': 988140.0,
#   'low_price': 920000.0,
#   'trade_price': 940440.0,
#   'timestamp': 1679529299445,
#   'candle_acc_trade_price': 2102265.3958288,
#   'candle_acc_trade_volume': 2.16868093,
#   'prev_closing_price': 961560.0,
#   'change_price': -21120.0,
#   'change_rate': -0.021964308},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-21T00:00:00',
#   'opening_price': 949720.0,
#   'high_price': 975500.0,
#   'low_price': 944700.0,
#   'trade_price': 961560.0,
#   'timestamp': 1679443083443,
#   'candle_acc_trade_price': 2357203.5818142,
#   'candle_acc_trade_volume': 2.46150376,
#   'prev_closing_price': 945980.0,
#   'change_price': 15580.0,
#   'change_rate': 0.0164696928},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-20T00:00:00',
#   'opening_price': 945920.0,
#   'high_price': 967780.0,
#   'low_price': 929000.0,
#   'trade_price': 945980.0,
#   'timestamp': 1679355726493,
#   'candle_acc_trade_price': 756364.8741672,
#   'candle_acc_trade_volume': 0.79507775,
#   'prev_closing_price': 960000.0,
#   'change_price': -14020.0,
#   'change_rate': -0.0146041667},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-19T00:00:00',
#   'opening_price': 920180.0,
#   'high_price': 960000.0,
#   'low_price': 916580.0,
#   'trade_price': 960000.0,
#   'timestamp': 1679268864017,
#   'candle_acc_trade_price': 551877.6120856,
#   'candle_acc_trade_volume': 0.58410643,
#   'prev_closing_price': 935100.0,
#   'change_price': 24900.0,
#   'change_rate': 0.0266281681},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-18T00:00:00',
#   'opening_price': 923700.0,
#   'high_price': 936540.0,
#   'low_price': 908320.0,
#   'trade_price': 935100.0,
#   'timestamp': 1679173833898,
#   'candle_acc_trade_price': 888901.8030112,
#   'candle_acc_trade_volume': 0.96636051,
#   'prev_closing_price': 929680.0,
#   'change_price': 5420.0,
#   'change_rate': 0.005829963},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-17T00:00:00',
#   'opening_price': 866940.0,
#   'high_price': 940080.0,
#   'low_price': 865000.0,
#   'trade_price': 929680.0,
#   'timestamp': 1679096147297,
#   'candle_acc_trade_price': 824582.1538912,
#   'candle_acc_trade_volume': 0.90895087,
#   'prev_closing_price': 864720.0,
#   'change_price': 64960.0,
#   'change_rate': 0.075122583},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-16T00:00:00',
#   'opening_price': 841000.0,
#   'high_price': 864720.0,
#   'low_price': 838340.0,
#   'trade_price': 864720.0,
#   'timestamp': 1679008490145,
#   'candle_acc_trade_price': 669480.433809,
#   'candle_acc_trade_volume': 0.78918002,
#   'prev_closing_price': 844960.0,
#   'change_price': 19760.0,
#   'change_rate': 0.0233857224},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-15T00:00:00',
#   'opening_price': 850700.0,
#   'high_price': 860940.0,
#   'low_price': 832140.0,
#   'trade_price': 844960.0,
#   'timestamp': 1678924315490,
#   'candle_acc_trade_price': 2135798.3775146,
#   'candle_acc_trade_volume': 2.50394817,
#   'prev_closing_price': 850580.0,
#   'change_price': -5620.0,
#   'change_rate': -0.0066072562},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-14T00:00:00',
#   'opening_price': 831280.0,
#   'high_price': 904600.0,
#   'low_price': 822160.0,
#   'trade_price': 850580.0,
#   'timestamp': 1678835628277,
#   'candle_acc_trade_price': 2683246.9552762,
#   'candle_acc_trade_volume': 3.12190218,
#   'prev_closing_price': 831280.0,
#   'change_price': 19300.0,
#   'change_rate': 0.0232172072},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-13T00:00:00',
#   'opening_price': 758160.0,
#   'high_price': 839020.0,
#   'low_price': 754380.0,
#   'trade_price': 831280.0,
#   'timestamp': 1678751098680,
#   'candle_acc_trade_price': 3588435.0320104,
#   'candle_acc_trade_volume': 4.59540292,
#   'prev_closing_price': 754600.0,
#   'change_price': 76680.0,
#   'change_rate': 0.1016167506},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-12T00:00:00',
#   'opening_price': 709000.0,
#   'high_price': 760460.0,
#   'low_price': 708000.0,
#   'trade_price': 754600.0,
#   'timestamp': 1678664830575,
#   'candle_acc_trade_price': 1388831.1611724,
#   'candle_acc_trade_volume': 1.89903583,
#   'prev_closing_price': 696020.0,
#   'change_price': 58580.0,
#   'change_rate': 0.0841642482},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-11T00:00:00',
#   'opening_price': 723340.0,
#   'high_price': 723340.0,
#   'low_price': 690660.0,
#   'trade_price': 696020.0,
#   'timestamp': 1678548278532,
#   'candle_acc_trade_price': 1481866.6686458,
#   'candle_acc_trade_volume': 2.11431376,
#   'prev_closing_price': 691900.0,
#   'change_price': 4120.0,
#   'change_rate': 0.0059546177},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-10T00:00:00',
#   'opening_price': 719240.0,
#   'high_price': 720520.0,
#   'low_price': 691900.0,
#   'trade_price': 691900.0,
#   'timestamp': 1678468881879,
#   'candle_acc_trade_price': 2495003.3520554,
#   'candle_acc_trade_volume': 3.53236756,
#   'prev_closing_price': 718500.0,
#   'change_price': -26600.0,
#   'change_rate': -0.0370215727},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-09T00:00:00',
#   'opening_price': 760020.0,
#   'high_price': 766620.0,
#   'low_price': 705260.0,
#   'trade_price': 718500.0,
#   'timestamp': 1678406151508,
#   'candle_acc_trade_price': 3645206.8354428,
#   'candle_acc_trade_volume': 4.9010174,
#   'prev_closing_price': 764400.0,
#   'change_price': -45900.0,
#   'change_rate': -0.0600470958},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-08T00:00:00',
#   'opening_price': 776640.0,
#   'high_price': 776640.0,
#   'low_price': 763900.0,
#   'trade_price': 764400.0,
#   'timestamp': 1678317044372,
#   'candle_acc_trade_price': 511962.0906648,
#   'candle_acc_trade_volume': 0.6622265,
#   'prev_closing_price': 769520.0,
#   'change_price': -5120.0,
#   'change_rate': -0.0066534983},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-07T00:00:00',
#   'opening_price': 769860.0,
#   'high_price': 770400.0,
#   'low_price': 769520.0,
#   'trade_price': 769520.0,
#   'timestamp': 1678201268749,
#   'candle_acc_trade_price': 86833.5755102,
#   'candle_acc_trade_volume': 0.11271468,
#   'prev_closing_price': 769520.0,
#   'change_price': None,
#   'change_rate': 0},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-06T00:00:00',
#   'opening_price': 775880.0,
#   'high_price': 775880.0,
#   'low_price': 769520.0,
#   'trade_price': 769520.0,
#   'timestamp': 1678084900563,
#   'candle_acc_trade_price': 2014.2667652,
#   'candle_acc_trade_volume': 0.00261541,
#   'prev_closing_price': 780300.0,
#   'change_price': -10780.0,
#   'change_rate': -0.0138151993},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-05T00:00:00',
#   'opening_price': 775000.0,
#   'high_price': 786560.0,
#   'low_price': 772540.0,
#   'trade_price': 780300.0,
#   'timestamp': 1678053365308,
#   'candle_acc_trade_price': 1336765.2266244,
#   'candle_acc_trade_volume': 1.71284994,
#   'prev_closing_price': 770000.0,
#   'change_price': 10300.0,
#   'change_rate': 0.0133766234},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-04T00:00:00',
#   'opening_price': 779540.0,
#   'high_price': 785940.0,
#   'low_price': 764020.0,
#   'trade_price': 770000.0,
#   'timestamp': 1677971648566,
#   'candle_acc_trade_price': 1776397.764697,
#   'candle_acc_trade_volume': 2.29432958,
#   'prev_closing_price': 770000.0,
#   'change_price': None,
#   'change_rate': 0},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-03T00:00:00',
#   'opening_price': 814000.0,
#   'high_price': 814000.0,
#   'low_price': 770000.0,
#   'trade_price': 770000.0,
#   'timestamp': 1677878408408,
#   'candle_acc_trade_price': 4615792.3920682,
#   'candle_acc_trade_volume': 5.86287595,
#   'prev_closing_price': 813980.0,
#   'change_price': -43980.0,
#   'change_rate': -0.0540308116},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-02T00:00:00',
#   'opening_price': 822740.0,
#   'high_price': 822740.0,
#   'low_price': 810000.0,
#   'trade_price': 813980.0,
#   'timestamp': 1677779286865,
#   'candle_acc_trade_price': 97820.1839422,
#   'candle_acc_trade_volume': 0.11988417,
#   'prev_closing_price': 814100.0,
#   'change_price': -120.0,
#   'change_rate': -0.000147402},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-03-01T00:00:00',
#   'opening_price': 819320.0,
#   'high_price': 829880.0,
#   'low_price': 814100.0,
#   'trade_price': 814100.0,
#   'timestamp': 1677700245773,
#   'candle_acc_trade_price': 350343.4953206,
#   'candle_acc_trade_volume': 0.42361731,
#   'prev_closing_price': 817040.0,
#   'change_price': -2940.0,
#   'change_rate': -0.003598355},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-02-28T00:00:00',
#   'opening_price': 825540.0,
#   'high_price': 825600.0,
#   'low_price': 815600.0,
#   'trade_price': 817040.0,
#   'timestamp': 1677614594609,
#   'candle_acc_trade_price': 995730.5783968,
#   'candle_acc_trade_volume': 1.20911294,
#   'prev_closing_price': 822540.0,
#   'change_price': -5500.0,
#   'change_rate': -0.0066866049},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-02-27T00:00:00',
#   'opening_price': 820280.0,
#   'high_price': 828820.0,
#   'low_price': 813920.0,
#   'trade_price': 822540.0,
#   'timestamp': 1677538156416,
#   'candle_acc_trade_price': 329489.4232938,
#   'candle_acc_trade_volume': 0.40175319,
#   'prev_closing_price': 819960.0,
#   'change_price': 2580.0,
#   'change_rate': 0.003146495},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-02-26T00:00:00',
#   'opening_price': 814540.0,
#   'high_price': 822440.0,
#   'low_price': 810980.0,
#   'trade_price': 819960.0,
#   'timestamp': 1677452743283,
#   'candle_acc_trade_price': 307204.1536062,
#   'candle_acc_trade_volume': 0.37538349,
#   'prev_closing_price': 805000.0,
#   'change_price': 14960.0,
#   'change_rate': 0.0185838509},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-02-25T00:00:00',
#   'opening_price': 814300.0,
#   'high_price': 814300.0,
#   'low_price': 796220.0,
#   'trade_price': 805000.0,
#   'timestamp': 1677365631336,
#   'candle_acc_trade_price': 99065.7824104,
#   'candle_acc_trade_volume': 0.1230726,
#   'prev_closing_price': 807280.0,
#   'change_price': -2280.0,
#   'change_rate': -0.0028242989},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-02-24T00:00:00',
#   'opening_price': 832980.0,
#   'high_price': 832980.0,
#   'low_price': 804460.0,
#   'trade_price': 807280.0,
#   'timestamp': 1677282889196,
#   'candle_acc_trade_price': 991233.9707056,
#   'candle_acc_trade_volume': 1.20015035,
#   'prev_closing_price': 833040.0,
#   'change_price': -25760.0,
#   'change_rate': -0.0309228849},
#  {'market': 'THB-BTC',
#   'candle_date_time_utc': '2023-02-23T00:00:00',
#   'opening_price': 838000.0,
#   'high_price': 848240.0,
#   'low_price': 821700.0,
#   'trade_price': 833040.0,
#   'timestamp': 1677194023718,
#   'candle_acc_trade_price': 272158.237313,
#   'candle_acc_trade_volume': 0.32272332,
#   'prev_closing_price': 829980.0,
#   'change_price': 3060.0,
#   'change_rate': 0.0036868358}]

# %%
df.info()

# %%
df.head()

# %%
result_df = pd.DataFrame()
result_df['timestamp'] = df['candle_date_time_utc']
result_df['open'] = df['opening_price']
result_df['high'] = df['high_price']
result_df['low'] = df['low_price']
result_df['close'] = df['prev_closing_price']

# %%
result_df

# %% [markdown]
# ## 2. calculate and display

# %%
maximum_closing_price = result_df['close'].max()
maximum_closing_price_rows = result_df[result_df['close'] == maximum_closing_price]
print(maximum_closing_price_rows)

# %%
minimum_closing_price = result_df['close'].min()
minimun_closing_price_rows = result_df[result_df['close'] == minimum_closing_price]
print(minimun_closing_price_rows)

# %%
avg_price = result_df['close'].mean()
print(avg_price)

# %% [markdown]
# ## 3. price changing

# %%
result_df['price_changing'] = result_df['close'].diff()
result_df

# %% [markdown]
# ## 4. Filter table

# %%
filterd_df = result_df[result_df['price_changing']>10000]
filterd_df = filterd_df.head()

# %% [markdown]
# ## 5. Correlation price_changing and high

# %%
correlation = filterd_df['price_changing'].corr(filterd_df['high'])

# %%
correlation

# %%
filterd_df.to_csv('upbit_data.csv')
